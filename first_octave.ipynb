# %% [markdown]
# # Octave Tutorial

# %%
3
# Out:
# ans =  3

# %%
t = linspace(0,6*pi,100);
plot(sin(t))
grid on
hold on
plot(cos(t), 'r')

# %%
help eig
# Out:
# 'eig' is a built-in function from the file libinterp/corefcn/eig.cc
#
#  -- Built-in Function: LAMBDA = eig (A)
#  -- Built-in Function: LAMBDA = eig (A, B)
#  -- Built-in Function: [V, LAMBDA] = eig (A)
#  -- Built-in Function: [V, LAMBDA] = eig (A, B)
#      Compute the eigenvalues (and optionally the eigenvectors) of a
#      matrix or a pair of matrices
#
#      The algorithm used depends on whether there are one or two input
#      matrices, if they are real or complex, and if they are symmetric
#      (Hermitian if complex) or non-symmetric.
#
#      The eigenvalues returned by `eig' are not ordered.
#
#      See also: eigs, svd.
#
#
# Additional help for built-in functions and operators is
# available in the online version of the manual.  Use the command
# 'doc <topic>' to search the manual index.
#
# Help and information about Octave is also available on the WWW
# at http://www.octave.org and via the help@octave.org
# mailing list.

# %%
3 , 2
# Out:
# ans =  3
# ans =  2

# %%
whos
# Out:
# Variables in the current scope:
#
#    Attr Name            Size                     Bytes  Class
#    ==== ====            ====                     =====  =====
#         ans             1x1                          8  double
#         figHandles      0x1                          0  double
#
# Total is 1 element using 8 bytes

# %%
# executes script named "doless.m" in current directory
doless

# %%
# the current enviroment variables can be seen with the command "whos"
whos
# Out:
# Variables in the current scope:
#
#    Attr Name            Size                     Bytes  Class
#    ==== ====            ====                     =====  =====
#         ans             1x1                          8  double
#         figHandles      0x1                          0  double
#         one             1x1                          8  double
#         three           1x1                          8  double
#         two             1x1                          8  double
#
# Total is 4 elements using 32 bytes

# %%
row_v = [1 2 3]
# Out:
# row_v =
#
#    1   2   3

# %%
col_v = [3;2;1]
# Out:
# col_v =
#
#    3
#    2
#    1

# %%
#vector generation [start: <increment :> end:]
[-2: 0.2 : 2.8]
# Out:
# ans =
#
#  Columns 1 through 8:
#
#   -2.00000  -1.80000  -1.60000  -1.40000  -1.20000  -1.00000  -0.80000  -0.60000
#
#  Columns 9 through 16:
#
#   -0.40000  -0.20000   0.00000   0.20000   0.40000   0.60000   0.80000   1.00000
#
#  Columns 17 through 24:
#
#    1.20000   1.40000   1.60000   1.80000   2.00000   2.20000   2.40000   2.60000
#
#  Column 25:
#
#    2.80000

# %%
A = [ 1 2 ; 3 4]
# Out:
# A =
#
#    1   2
#    3   4

# %%
b = [5;6]
# Out:
# b =
#
#    5
#    6

# %%
[A b]
# Out:
# ans =
#
#    1   2   5
#    3   4   6

# %%
B = ones(2,2) * 2
# Out:
# B =
#
#    2   2
#    2   2

# %%
A*B, A+B
# Out:
# ans =
#
#     6    6
#    14   14
#
# ans =
#
#    3   4
#    5   6

# %%
# "." gives element-wise operations
A.*B
# Out:
# ans =
#
#    2   4
#    6   8

# %%
#indexing is 1-based 
A(1,1)
# Out:
# ans =  1

# %%
#slicing works intuitively
A(1:2,2)
# Out:
# ans =
#
#    2
#    4

# %%
size(A)
# Out:
# ans =
#
#    2   2

# %%
length([A b])
# Out:
# ans =  3

# %%
# returs col vector for the diagonal of A
diag(A)
# Out:
# ans =
#
#    1
#    4

# %%
x = -2:0.1:2;
[xx,yy] = meshgrid(x,x);
z = sin(xx.^2 - yy.^2)
mesh(x,x,z)
# Out:
# z =
#
#  Columns 1 through 8:
#
#    0.00000  -0.38019  -0.68892  -0.89570  -0.99146  -0.98399  -0.89193  -0.73901
#    0.38019   0.00000  -0.36162  -0.65938  -0.86742  -0.97786  -0.99687  -0.93965
#    0.68892   0.36162   0.00000  -0.34290  -0.62879  -0.83603  -0.95802  -0.99978
#    0.89570   0.65938   0.34290   0.00000  -0.32404  -0.59720  -0.80162  -0.93204
#    0.99146   0.86742   0.62879   0.32404   0.00000  -0.30506  -0.56464  -0.76433
#    0.98399   0.97786   0.83603   0.59720   0.30506   0.00000  -0.28595  -0.53119
#    0.89193   0.99687   0.95802   0.80162   0.56464   0.28595   0.00000  -0.26673
#    0.73901   0.93965   0.99978   0.93204   0.76433   0.53119   0.26673   0.00000
#    0.54936   0.82578   0.97385   0.99271   0.90010   0.72429   0.49688   0.24740
#    0.34439   0.67546   0.89641   0.99404   0.97572   0.86240   0.68164   0.46178
#    0.14112   0.50691   0.78432   0.94949   0.99994   0.94898   0.81919   0.63654
# ...

# %%
A,B,A+B,trace(A+B),A*B,trace(A*B)
# Out:
# A =
#
#    1   2
#    3   4
#
# B =
#
#    2   2
#    2   2
#
# ans =
#
#    3   4
#    5   6
#
# ans =  9
# ans =
#
#     6    6
#    14   14
#
# ans =  20

# %%
pinv(A)
# Out:
# ans =
#
#   -2.00000   1.00000
#    1.50000  -0.50000

# %%
pinv(A)* A
# Out:
# ans =
#
#    1.0000e+00  -8.8818e-16
#   -4.4409e-16   1.0000e+00

# %%
for i=1:5
    rand()
end
# Out:
# ans =  0.48136
# ans =  0.93412
# ans =  0.81158
# ans =  0.10110
# ans =  0.68060
